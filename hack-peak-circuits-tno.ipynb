# %%
from utils import contract_core, tno_to_tne, extract_bitstring, iter_layers
from qiskit import QuantumCircuit
import time

# %% [markdown]
# ### Load circuits

# %%
circuit = QuantumCircuit.from_qasm_file("heavy_hex_49_4020.qasm")

# %% [markdown]
# ### Separate circuit into layers

# %%
t0 = time.perf_counter()
circuit_layers = list(iter_layers(circuit))

# %% [markdown]
# ### Start a TNO at the center of the circuit and iteratively merge and contract layers into it

# %%
tno, _ = contract_core(circuit_layers, chunk_size=2, cutoff=0.01, max_bond=16)
tno
# Out:
# /home/ubuntu/.venv/lib/python3.11/site-packages/torch/cuda/__init__.py:829: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
#     (|220-221|-222-|223-224|)/(445) -> max_bond = 2, max_links = 4, total_elems = 688, total_shapes = 368
#     (|218-219|-222-|225-226|)/(445) -> max_bond = 4, max_links = 4, total_elems = 688, total_shapes = 362
#     (|216-217|-222-|227-228|)/(445) -> max_bond = 4, max_links = 4, total_elems = 712, total_shapes = 368
#     (|214-215|-222-|229-230|)/(445) -> max_bond = 4, max_links = 4, total_elems = 776, total_shapes = 376
#     (|212-213|-222-|231-232|)/(445) -> max_bond = 4, max_links = 4, total_elems = 712, total_shapes = 364
#     (|210-211|-222-|233-234|)/(445) -> max_bond = 4, max_links = 4, total_elems = 812, total_shapes = 382
#     (|208-209|-222-|235-236|)/(445) -> max_bond = 4, max_links = 4, total_elems = 876, total_shapes = 390
#     (|206-207|-222-|237-238|)/(445) -> max_bond = 4, max_links = 4, total_elems = 844, total_shapes = 378
#     (|204-205|-222-|239-240|)/(445) -> max_bond = 4, max_links = 4, total_elems = 876, total_shapes = 386
#     (|202-203|-222-|241-242|)/(445) -> max_bond = 4, max_links = 4, total_elems = 776, total_shapes = 380
#     (|200-201|-222-|243-244|)/(445) -> max_bond = 4, max_links = 4, total_elems = 800, total_shapes = 376
#     (|198-199|-222-|245-246|)/(445) -> max_bond = 4, max_links = 4, total_elems = 776, total_shapes = 380
#     (|196-197|-222-|247-248|)/(445) -> max_bond = 4, max_links = 4, total_elems = 792, total_shapes = 380
#     (|194-195|-222-|249-250|)/(445) -> max_bond = 4, max_links = 4, total_elems = 772, total_shapes = 374
#     (|192-193|-222-|251-252|)/(445) -> max_bond = 4, max_links = 4, total_elems = 872, total_shapes = 390
#     (|190-191|-222-|253-254|)/(445) -> max_bond = 7, max_links = 4, total_elems = 760, total_shapes = 372
#     (|188-189|-222-|255-256|)/(445) -> max_bond = 4, max_links = 4, total_elems = 704, total_shapes = 354
#     (|186-187|-222-|257-258|)/(445) -> max_bond = 6, max_links = 4, total_elems = 732, total_shapes = 366
#     (|184-185|-222-|259-260|)/(445) -> max_bond = 6, max_links = 4, total_elems = 840, total_shapes = 382
#     (|182-183|-222-|261-262|)/(445) -> max_bond = 4, max_links = 4, total_elems = 852, total_shapes = 384
#     (|180-181|-222-|263-264|)/(445) -> max_bond = 4, max_links = 4, total_elems = 776, total_shapes = 380
#     (|178-179|-222-|265-266|)/(445) -> max_bond = 4, max_links = 4, total_elems = 816, total_shapes = 386
#     (|176-177|-222-|267-268|)/(445) -> max_bond = 4, max_links = 4, total_elems = 728, total_shapes = 368
#     (|174-175|-222-|269-270|)/(445) -> max_bond = 4, max_links = 4, total_elems = 828, total_shapes = 384
#     (|172-173|-222-|271-272|)/(445) -> max_bond = 4, max_links = 4, total_elems = 872, total_shapes = 394
#     (|170-171|-222-|273-274|)/(445) -> max_bond = 4, max_links = 4, total_elems = 904, total_shapes = 392
#     (|168-169|-222-|275-276|)/(445) -> max_bond = 4, max_links = 4, total_elems = 828, total_shapes = 386
#     (|166-167|-222-|277-278|)/(445) -> max_bond = 4, max_links = 4, total_elems = 796, total_shapes = 380
#     (|164-165|-222-|279-280|)/(445) -> max_bond = 4, max_links = 4, total_elems = 792, total_shapes = 376
#     (|162-163|-222-|281-282|)/(445) -> max_bond = 4, max_links = 4, total_elems = 756, total_shapes = 378
#     (|160-161|-222-|283-284|)/(445) -> max_bond = 4, max_links = 4, total_elems = 736, total_shapes = 368
#     (|158-159|-222-|285-286|)/(445) -> max_bond = 4, max_links = 4, total_elems = 752, total_shapes = 372
#     (|156-157|-222-|287-288|)/(445) -> max_bond = 4, max_links = 4, total_elems = 720, total_shapes = 368
#     (|154-155|-222-|289-290|)/(445) -> max_bond = 4, max_links = 4, total_elems = 800, total_shapes = 378
#     (|152-153|-222-|291-292|)/(445) -> max_bond = 6, max_links = 4, total_elems = 820, total_shapes = 372
#     (|150-151|-222-|293-294|)/(445) -> max_bond = 4, max_links = 4, total_elems = 908, total_shapes = 390
#     (|148-149|-222-|295-296|)/(445) -> max_bond = 4, max_links = 4, total_elems = 876, total_shapes = 390
#     (|146-147|-222-|297-298|)/(445) -> max_bond = 4, max_links = 4, total_elems = 844, total_shapes = 390
#     (|144-145|-222-|299-300|)/(445) -> max_bond = 4, max_links = 4, total_elems = 880, total_shapes = 392
#     (|142-143|-222-|301-302|)/(445) -> max_bond = 4, max_links = 4, total_elems = 808, total_shapes = 384
#     (|140-141|-222-|303-304|)/(445) -> max_bond = 4, max_links = 4, total_elems = 724, total_shapes = 366
#     (|138-139|-222-|305-306|)/(445) -> max_bond = 4, max_links = 4, total_elems = 648, total_shapes = 356
#     (|136-137|-222-|307-308|)/(445) -> max_bond = 4, max_links = 4, total_elems = 676, total_shapes = 362
#     (|134-135|-222-|309-310|)/(445) -> max_bond = 4, max_links = 4, total_elems = 608, total_shapes = 346
#     (|132-133|-222-|311-312|)/(445) -> max_bond = 4, max_links = 4, total_elems = 680, total_shapes = 362
#     (|130-131|-222-|313-314|)/(445) -> max_bond = 4, max_links = 4, total_elems = 720, total_shapes = 368
#     (|128-129|-222-|315-316|)/(445) -> max_bond = 4, max_links = 4, total_elems = 768, total_shapes = 366
#     (|126-127|-222-|317-318|)/(445) -> max_bond = 4, max_links = 4, total_elems = 752, total_shapes = 370
#     (|124-125|-222-|319-320|)/(445) -> max_bond = 4, max_links = 4, total_elems = 652, total_shapes = 356
#     (|122-123|-222-|321-322|)/(445) -> max_bond = 4, max_links = 4, total_elems = 612, total_shapes = 344
#     (|120-121|-222-|323-324|)/(445) -> max_bond = 4, max_links = 4, total_elems = 656, total_shapes = 356
#     (|118-119|-222-|325-326|)/(445) -> max_bond = 4, max_links = 4, total_elems = 824, total_shapes = 378
#     (|116-117|-222-|327-328|)/(445) -> max_bond = 4, max_links = 4, total_elems = 760, total_shapes = 366
#     (|114-115|-222-|329-330|)/(445) -> max_bond = 6, max_links = 4, total_elems = 868, total_shapes = 392
#     (|112-113|-222-|331-332|)/(445) -> max_bond = 4, max_links = 4, total_elems = 976, total_shapes = 400
#     (|110-111|-222-|333-334|)/(445) -> max_bond = 4, max_links = 4, total_elems = 888, total_shapes = 384
#     (|108-109|-222-|335-336|)/(445) -> max_bond = 4, max_links = 4, total_elems = 920, total_shapes = 392
#     (|106-107|-222-|337-338|)/(445) -> max_bond = 5, max_links = 4, total_elems = 836, total_shapes = 380
#     (|104-105|-222-|339-340|)/(445) -> max_bond = 4, max_links = 4, total_elems = 768, total_shapes = 366
#     (|102-103|-222-|341-342|)/(445) -> max_bond = 4, max_links = 4, total_elems = 660, total_shapes = 358
#     (|100-101|-222-|343-344|)/(445) -> max_bond = 4, max_links = 4, total_elems = 688, total_shapes = 364
#     (|98-99|-222-|345-346|)/(445) -> max_bond = 4, max_links = 4, total_elems = 684, total_shapes = 362
#     (|96-97|-222-|347-348|)/(445) -> max_bond = 4, max_links = 4, total_elems = 784, total_shapes = 382
#     (|94-95|-222-|349-350|)/(445) -> max_bond = 4, max_links = 4, total_elems = 788, total_shapes = 380
#     (|92-93|-222-|351-352|)/(445) -> max_bond = 4, max_links = 4, total_elems = 788, total_shapes = 370
#     (|90-91|-222-|353-354|)/(445) -> max_bond = 4, max_links = 4, total_elems = 852, total_shapes = 384
#     (|88-89|-222-|355-356|)/(445) -> max_bond = 4, max_links = 4, total_elems = 800, total_shapes = 382
#     (|86-87|-222-|357-358|)/(445) -> max_bond = 4, max_links = 4, total_elems = 708, total_shapes = 364
#     (|84-85|-222-|359-360|)/(445) -> max_bond = 4, max_links = 4, total_elems = 680, total_shapes = 364
#     (|82-83|-222-|361-362|)/(445) -> max_bond = 4, max_links = 4, total_elems = 720, total_shapes = 368
#     (|80-81|-222-|363-364|)/(445) -> max_bond = 4, max_links = 4, total_elems = 772, total_shapes = 376
#     (|78-79|-222-|365-366|)/(445) -> max_bond = 4, max_links = 4, total_elems = 744, total_shapes = 376
#     (|76-77|-222-|367-368|)/(445) -> max_bond = 4, max_links = 4, total_elems = 744, total_shapes = 372
#     (|74-75|-222-|369-370|)/(445) -> max_bond = 4, max_links = 4, total_elems = 704, total_shapes = 364
#     (|72-73|-222-|371-372|)/(445) -> max_bond = 4, max_links = 4, total_elems = 768, total_shapes = 376
#     (|70-71|-222-|373-374|)/(445) -> max_bond = 4, max_links = 4, total_elems = 792, total_shapes = 376
#     (|68-69|-222-|375-376|)/(445) -> max_bond = 4, max_links = 4, total_elems = 816, total_shapes = 374
#     (|66-67|-222-|377-378|)/(445) -> max_bond = 4, max_links = 4, total_elems = 800, total_shapes = 380
#     (|64-65|-222-|379-380|)/(445) -> max_bond = 4, max_links = 4, total_elems = 784, total_shapes = 380
#     (|62-63|-222-|381-382|)/(445) -> max_bond = 4, max_links = 4, total_elems = 752, total_shapes = 376
#     (|60-61|-222-|383-384|)/(445) -> max_bond = 4, max_links = 4, total_elems = 808, total_shapes = 378
#     (|58-59|-222-|385-386|)/(445) -> max_bond = 4, max_links = 4, total_elems = 792, total_shapes = 378
#     (|56-57|-222-|387-388|)/(445) -> max_bond = 4, max_links = 4, total_elems = 788, total_shapes = 374
#     (|54-55|-222-|389-390|)/(445) -> max_bond = 4, max_links = 4, total_elems = 708, total_shapes = 362
#     (|52-53|-222-|391-392|)/(445) -> max_bond = 4, max_links = 4, total_elems = 792, total_shapes = 376
#     (|50-51|-222-|393-394|)/(445) -> max_bond = 4, max_links = 4, total_elems = 780, total_shapes = 374
#     (|48-49|-222-|395-396|)/(445) -> max_bond = 4, max_links = 4, total_elems = 744, total_shapes = 372
#     (|46-47|-222-|397-398|)/(445) -> max_bond = 4, max_links = 4, total_elems = 760, total_shapes = 372
#     (|44-45|-222-|399-400|)/(445) -> max_bond = 4, max_links = 4, total_elems = 720, total_shapes = 362
#     (|42-43|-222-|401-402|)/(445) -> max_bond = 4, max_links = 4, total_elems = 752, total_shapes = 372
#     (|40-41|-222-|403-404|)/(445) -> max_bond = 4, max_links = 4, total_elems = 752, total_shapes = 374
#     (|38-39|-222-|405-406|)/(445) -> max_bond = 4, max_links = 4, total_elems = 876, total_shapes = 384
#     (|36-37|-222-|407-408|)/(445) -> max_bond = 4, max_links = 4, total_elems = 876, total_shapes = 392
#     (|34-35|-222-|409-410|)/(445) -> max_bond = 4, max_links = 4, total_elems = 852, total_shapes = 388
#     (|32-33|-222-|411-412|)/(445) -> max_bond = 4, max_links = 4, total_elems = 860, total_shapes = 380
#     (|30-31|-222-|413-414|)/(445) -> max_bond = 4, max_links = 4, total_elems = 876, total_shapes = 390
#     (|28-29|-222-|415-416|)/(445) -> max_bond = 4, max_links = 4, total_elems = 832, total_shapes = 388
#     (|26-27|-222-|417-418|)/(445) -> max_bond = 4, max_links = 4, total_elems = 780, total_shapes = 378
#     (|24-25|-222-|419-420|)/(445) -> max_bond = 4, max_links = 4, total_elems = 744, total_shapes = 374
#     (|22-23|-222-|421-422|)/(445) -> max_bond = 4, max_links = 4, total_elems = 768, total_shapes = 376
#     (|20-21|-222-|423-424|)/(445) -> max_bond = 4, max_links = 4, total_elems = 764, total_shapes = 374
#     (|18-19|-222-|425-426|)/(445) -> max_bond = 4, max_links = 4, total_elems = 792, total_shapes = 382
#     (|16-17|-222-|427-428|)/(445) -> max_bond = 4, max_links = 4, total_elems = 816, total_shapes = 384
#     (|14-15|-222-|429-430|)/(445) -> max_bond = 4, max_links = 4, total_elems = 772, total_shapes = 374
#     (|12-13|-222-|431-432|)/(445) -> max_bond = 4, max_links = 4, total_elems = 720, total_shapes = 368
#     (|10-11|-222-|433-434|)/(445) -> max_bond = 4, max_links = 4, total_elems = 748, total_shapes = 372
#     (|8-9|-222-|435-436|)/(445) -> max_bond = 4, max_links = 4, total_elems = 692, total_shapes = 358
#     (|6-7|-222-|437-438|)/(445) -> max_bond = 4, max_links = 4, total_elems = 752, total_shapes = 374
#     (|4-5|-222-|439-440|)/(445) -> max_bond = 6, max_links = 5, total_elems = 1112, total_shapes = 424
#     (|2-3|-222-|441-442|)/(445) -> max_bond = 8, max_links = 5, total_elems = 2176, total_shapes = 506
#     (|0-1|-222-|443-444|)/(445) -> max_bond = 8, max_links = 5, total_elems = 4852, total_shapes = 636
#     (|-1--1|-222-|445-445|)/(445) -> max_bond = 8, max_links = 5, total_elems = 4580, total_shapes = 622
# TensorNetworkGenOperator(tensors=49, indices=150)

# %% [markdown]
# ### Apply the TNO to the |0> state

# %%
tne = tno_to_tne(tno, max_bond=8, cutoff=0.01)
# Out:
# max_bond = 3, max_links = 4

# %% [markdown]
# ### Extract the bitstring with single-bit marginals

# %%
pred_bitstring, qubit_marginals = extract_bitstring(tne)
# Out:
# /home/ubuntu/.venv/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:8590: UserWarning: The contraction tree is not a compressed one, this may be very inefficient.
#   warnings.warn(

# %%
print(time.perf_counter() - t0)
# Out:
# 37.664408788084984
